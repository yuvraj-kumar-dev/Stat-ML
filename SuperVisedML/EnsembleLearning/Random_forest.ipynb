# %%
import pandas as pd

# %%
df = pd.read_excel('Raisin_Dataset.xlsx')
X = df.drop('Class', axis=1)
y = df['Class']

X.head()
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter
# 0  0.758651   1184.040
# 1  0.684130   1121.786
# 2  0.637613   1208.575
# 3  0.699599    844.162
# 4  0.792772   1073.251

# %% [markdown]
# ### Model Training using Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

pipeline = Pipeline([
    ('scale', StandardScaler()),('tree', DecisionTreeClassifier())
])

pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('tree', DecisionTreeClassifier())])

# %%
y_pred = pipeline.predict(X_test)

from sklearn.metrics import classification_report

result = classification_report(y_test, y_pred)

print(result)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.81      0.83      0.82        93
#      Kecimen       0.81      0.79      0.80        87
#
#     accuracy                           0.81       180
#    macro avg       0.81      0.81      0.81       180
# weighted avg       0.81      0.81      0.81       180

# %%
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

pipeline = Pipeline([
    ('scale', StandardScaler()),('tree', RandomForestClassifier(n_estimators=20))
])

pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('tree', RandomForestClassifier(n_estimators=20))])

# %%
y_pred = pipeline.predict(X_test)

from sklearn.metrics import classification_report

result = classification_report(y_test, y_pred)

print(result)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.89      0.85      0.87        93
#      Kecimen       0.85      0.89      0.87        87
#
#     accuracy                           0.87       180
#    macro avg       0.87      0.87      0.87       180
# weighted avg       0.87      0.87      0.87       180
