# %%
#House_Prediction using one independent variable (Simple Linear Regression)

from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
df = pd.read_csv('House_price.csv')
df.head()
# df.keys()
# Out:
#    Area_in_m2  Price_in_L
# 0         656        39.0
# 1        1260        83.2
# 2        1057        86.6
# 3        1259        59.0
# 4        1800       140.0

# %%
model = LinearRegression()
model.fit(df[['Area_in_m2']], df['Price_in_L'])
# Out:
# LinearRegression()

# %%
model.predict([[1500]])
# Out:
# C:\Users\yuvra\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([95.55881097])

# %%
model.coef_
# Out:
# array([0.05259152])

# %%
model.intercept_
# Out:
# np.float64(16.671536583415254)

# %%
0.0525*1500+16.6715
# Out:
# 95.42150000000001

# %%
df
# Out:
#     Area_in_m2  Price_in_L
# 0          656        39.0
# 1         1260        83.2
# 2         1057        86.6
# 3         1259        59.0
# 4         1800       140.0
# 5         1325        80.1
# 6         1085       116.0
# 7         1110        45.0
# 8         1700       100.0
# 9          960        89.0
# 10        1800        90.0
# 11         700        49.0
# 12         750        53.0
